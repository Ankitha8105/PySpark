# %% [markdown]
# '''
#     @Author:Ankitha
#     @Date: 01-01-2025
#     @Last Modified by: Ankitha
#     @Last Modified time: 02-01-2025
#     @Title :pyspark Word count problem using text file
# '''

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder \
    .appName("Word Count") \
    .getOrCreate()

file_path = "sampleData.txt" 
lines = spark.read.text(file_path).rdd

word_counts = (
    lines.flatMap(lambda line: line[0].split())  
    .map(lambda word: (word, 1))  
    .reduceByKey(lambda a, b: a + b)  
)

for word, count in word_counts.collect():
    print(f"{word}: {count}")

spark.stop()
# Out:
# Hii: 7
# Welcome: 7
# To: 7
# word: 7
# count: 7
# program: 7
